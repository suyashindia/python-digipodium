# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#histogram(bins,rug)
sns.set(style="darkgrid")
sns.displot(data["Annual Income (k$)"],bins=100,rug=True,color="r")
plt.show()

# %%
sns.distplot(data["Spending Score (1-100)"])
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#hue,#style,#palette(lineplot color will be changed)
sns.lineplot(x="Annual Income (k$)",y="Age",hue="Genre",style="Genre",palette="hot",data=data)
plt.show()

# %%
#dashes,markers
sns.set(style="darkgrid")#changes the background
plt.figure(figsize=(16,9)) #changes the size of graph
sns.lineplot(x="Annual Income (k$)",y="Age",hue="Genre",style="Genre",palette="hot",data=data,dashes=False,markers=["o","<"],legend="brief")
#if want to change titles then
plt.xlabel("Annual Income (k$)",fontsize=15)
plt.ylabel("Age",fontsize=15)
plt.title("Lineplot",fontsize=20)
plt.show()

# %%
sns.lineplot(x="Genre",y="Annual Income (k$)",data=data)
plt.show()

# %%
#linepplot seaborn
sns.lineplot(x="Annual Income (k$)",y="Age",data=data) #relationship between annual icome and age
plt.show()

# %%
data=pd.read_csv("https://raw.githubusercontent.com/digipodium/Datasets/main/Mall_Customers.csv")

# %%
data.tail()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.groupby("Genre").count().head( )
# Out:
#         CustomerID  Age  Annual Income (k$)  Spending Score (1-100)
# Genre
# Female         112  112                 112                     112
# Male            88   88                  88                      88

# %%
data["Age"].value_counts()
# Out:
# 32    11
# 35     9
# 19     8
# 31     8
# 30     7
# 49     7
# 40     6
# 38     6
# 47     6
# 27     6
# 36     6
# 23     6
# 34     5
# 20     5
# 29     5
# 50     5
# 48     5
# 21     5
# 24     4
# 18     4
# 28     4
# 67     4
# 59     4
# 54     4
# 43     3
# 60     3
# 45     3
# 39     3
# 33     3
# 37     3
# 22     3
# 25     3
# 46     3
# 68     3
# 52     2
# 44     2
# 66     2
# 57     2
# 26     2
# 53     2
# 42     2
# 63     2
# 70     2
# 51     2
# 58     2
# 65     2
# 41     2
# 55     1
# 69     1
# 64     1
# 56     1
# Name: Age, dtype: int64

# %%
data.Age[data.Genre=="Male"].value_counts()
# Out:
# 19    6
# 32    5
# 48    5
# 59    4
# 28    3
# 20    3
# 67    3
# 35    3
# 39    3
# 40    3
# 18    3
# 34    2
# 47    2
# 27    2
# 38    2
# 26    2
# 36    2
# 70    2
# 43    2
# 30    2
# 25    2
# 24    2
# 53    2
# 37    2
# 33    2
# 69    1
# 46    1
# 58    1
# 64    1
# 42    1
# 50    1
# 22    1
# 52    1
# 29    1
# 31    1
# 65    1
# 66    1
# 68    1
# 54    1
# 49    1
# 60    1
# 57    1
# 21    1
# 63    1
# Name: Age, dtype: int64

# %%
data.Age[data.Genre=="Female"].value_counts()
# Out:
# 31    7
# 23    6
# 49    6
# 32    6
# 35    6
# 30    5
# 38    4
# 29    4
# 27    4
# 50    4
# 47    4
# 36    4
# 21    4
# 40    3
# 45    3
# 54    3
# 34    3
# 60    2
# 68    2
# 19    2
# 44    2
# 20    2
# 41    2
# 22    2
# 46    2
# 24    2
# 51    2
# 43    1
# 37    1
# 52    1
# 33    1
# 56    1
# 28    1
# 57    1
# 63    1
# 25    1
# 18    1
# 58    1
# 66    1
# 55    1
# 42    1
# 65    1
# 67    1
# Name: Age, dtype: int64

# %%
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.drop(["CustomerID"],axis=1,inplace=True)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10184/945733576.py in <module>
# ----> 1 data.drop(["CustomerID"],axis=1,inplace=True)
#       2 data.head()
#
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
data.shape
# Out:
# (200, 5)

# %%
data.Age[data.Age==54].value_counts()
# Out:
# 54    4
# Name: Age, dtype: int64

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.columns.unique()
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64
