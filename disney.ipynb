# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
character=pd.read_csv("C:/Users/Dell/Downloads/disney1/data.csv")

# %%
data=pd.read_csv("C:/Users/Dell/Downloads/disney2/data.csv")

# %%
data.head()
# Out:
#         id                            title   type  \
# 0  tm74391                         Fantasia  MOVIE
# 1  tm67803  Snow White and the Seven Dwarfs  MOVIE
# 2  tm82546                        Pinocchio  MOVIE
# 3  tm79357                            Bambi  MOVIE
# 4  tm62671                  Treasure Island  MOVIE
#
#                                          description  release_year  \
# 0  Walt Disney's timeless masterpiece is an extra...          1940
# 1  A beautiful girl, Snow White, takes refuge in ...          1937
# 2  Lonely toymaker Geppetto has his wishes answer...          1940
# 3  Bambi's tale unfolds from season to season as ...          1942
# 4  Enchanted by the idea of locating treasure bur...          1950
#
#   age_certification  runtime  \
# 0                 G      120
# 1                 G       83
# 2                 G       88
# 3                 G       70
# 4                PG       96
#
# ...

# %%
data.tail()
# Out:
#              id                          title   type  \
# 1530  tm1071287  Killer Shark vs. Killer Whale  MOVIE
# 1531  tm1091101          Far From Raven's Home  MOVIE
# 1532  tm1075680  World's Most Dangerous Shark?  MOVIE
# 1533  tm1133820                The Magic Maker  MOVIE
# 1534  tm1091117    Smoky Mountain Park Rangers  MOVIE
#
#                                             description  release_year  \
# 1530  Scientists dive deep on the mysterious and unu...          2021
# 1531  Our gang is off for an exotic vacation of a li...          2021
# 1532  The Great White has a scary reputation, but Ex...          2021
# 1533  Famed magician Adam Trent breaks the number on...          2021
# 1534  Park Rangers work to protect and manage black ...          2021
#
#      age_certification  runtime                   genres production_countries  \
# 1530             PG-13       44        ['documentation']               ['US']
# ...

# %%
data.drop(data.columns[data.columns.str.contains("unnamed",case=False)],axis=1,inplace=True)

# %%
data.head()
# Out:
#         id                            title   type  \
# 0  tm74391                         Fantasia  MOVIE
# 1  tm67803  Snow White and the Seven Dwarfs  MOVIE
# 2  tm82546                        Pinocchio  MOVIE
# 3  tm79357                            Bambi  MOVIE
# 4  tm62671                  Treasure Island  MOVIE
#
#                                          description  release_year  \
# 0  Walt Disney's timeless masterpiece is an extra...          1940
# 1  A beautiful girl, Snow White, takes refuge in ...          1937
# 2  Lonely toymaker Geppetto has his wishes answer...          1940
# 3  Bambi's tale unfolds from season to season as ...          1942
# 4  Enchanted by the idea of locating treasure bur...          1950
#
#   age_certification  runtime  \
# 0                 G      120
# 1                 G       83
# 2                 G       88
# 3                 G       70
# 4                PG       96
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1535 entries, 0 to 1534
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1535 non-null   object
#  1   title                 1535 non-null   object
#  2   type                  1535 non-null   object
#  3   description           1529 non-null   object
#  4   release_year          1535 non-null   int64
#  5   age_certification     1210 non-null   object
#  6   runtime               1535 non-null   int64
#  7   genres                1535 non-null   object
#  8   production_countries  1535 non-null   object
#  9   seasons               415 non-null    float64
#  10  imdb_id               1133 non-null   object
#  11  imdb_score            1108 non-null   float64
#  12  imdb_votes            1105 non-null   float64
#  13  tmdb_popularity       1524 non-null   float64
#  14  tmdb_score            1426 non-null   float64
# ...

# %%
data.isnull().sum(axis=0).sort_values(ascending=False)
# Out:
# seasons                 1120
# imdb_votes               430
# imdb_score               427
# imdb_id                  402
# age_certification        325
# tmdb_score               109
# tmdb_popularity           11
# description                6
# id                         0
# title                      0
# type                       0
# release_year               0
# runtime                    0
# genres                     0
# production_countries       0
# dtype: int64

# %%
data.drop(["id","description","release_year","age_certification","runtime","seasons","imdb_id"],axis=1,inplace=True)

# %%
data.isnull().sum(axis=0).sort_values(ascending=False)
# Out:
# imdb_votes              430
# imdb_score              427
# tmdb_score              109
# tmdb_popularity          11
# title                     0
# type                      0
# genres                    0
# production_countries      0
# dtype: int64

# %%
round(data.isnull().sum().sort_values(ascending=False)/len(data)*100,2)
# Out:
# imdb_votes              28.01
# imdb_score              27.82
# tmdb_score               7.10
# tmdb_popularity          0.72
# title                    0.00
# type                     0.00
# genres                   0.00
# production_countries     0.00
# dtype: float64

# %%
data["imdb_votes"].notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1530     True
# 1531     True
# 1532    False
# 1533     True
# 1534    False
# Name: imdb_votes, Length: 1535, dtype: bool

# %%
data=data[data["imdb_votes"].notnull()]
data=data[data["imdb_score"].notnull()]
data=data[data["tmdb_score"].notnull()]
data=data[data["tmdb_popularity"].notnull()]

# %%
data.head()
# Out:
#                              title   type  \
# 0                         Fantasia  MOVIE
# 1  Snow White and the Seven Dwarfs  MOVIE
# 2                        Pinocchio  MOVIE
# 3                            Bambi  MOVIE
# 4                  Treasure Island  MOVIE
#
#                                               genres production_countries  \
# 0        ['animation', 'family', 'music', 'fantasy']               ['US']
# 1  ['fantasy', 'family', 'romance', 'animation', ...               ['US']
# 2       ['animation', 'comedy', 'family', 'fantasy']               ['US']
# 3                   ['animation', 'drama', 'family']               ['US']
# 4                               ['family', 'action']         ['GB', 'US']
#
#    imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0         7.7     94681.0           57.751         7.4
# 1         7.6    195321.0          107.137         7.1
# 2         7.5    141937.0           71.160         7.1
# ...

# %%
data.shape
# Out:
# (1057, 8)

# %%
data.rename(columns={"title":"movie"},inplace=True)

# %%
data.head(1)
# Out:
#       movie   type                                       genres  \
# 0  Fantasia  MOVIE  ['animation', 'family', 'music', 'fantasy']
#
#   production_countries  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0               ['US']         7.7     94681.0           57.751         7.4

# %%
data.movie.unique()
# Out:
# array(['Fantasia', 'Snow White and the Seven Dwarfs', 'Pinocchio', ...,
#        'Built for Mars: The Perseverance Rover',
#        'Killer Shark vs. Killer Whale', "Far From Raven's Home"],
#       dtype=object)

# %%
data.movie.value_counts()
# Out:
# Freaky Friday                           3
# Fantastic Four                          3
# DuckTales                               2
# Lady and the Tramp                      2
# Alice in Wonderland                     2
#                                        ..
# Confessions of a Teenage Drama Queen    1
# The Lizzie McGuire Movie                1
# The Game Plan                           1
# Eight Below                             1
# Far From Raven's Home                   1
# Name: movie, Length: 1024, dtype: int64

# %%
round(data.isnull().sum().sort_values(ascending=False)/len(data)*100,2)
# Out:
# movie                   0.0
# type                    0.0
# genres                  0.0
# production_countries    0.0
# imdb_score              0.0
# imdb_votes              0.0
# tmdb_popularity         0.0
# tmdb_score              0.0
# dtype: float64

# %%
data["production_countries"]=data["production_countries"].str.replace(r'[][]','',regex=True)

# %%
data.head()
# Out:
#                              movie   type  \
# 0                         Fantasia  MOVIE
# 1  Snow White and the Seven Dwarfs  MOVIE
# 2                        Pinocchio  MOVIE
# 3                            Bambi  MOVIE
# 4                  Treasure Island  MOVIE
#
#                                               genres production_countries  \
# 0        ['animation', 'family', 'music', 'fantasy']                 'US'
# 1  ['fantasy', 'family', 'romance', 'animation', ...                 'US'
# 2       ['animation', 'comedy', 'family', 'fantasy']                 'US'
# 3                   ['animation', 'drama', 'family']                 'US'
# 4                               ['family', 'action']           'GB', 'US'
#
#    imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0         7.7     94681.0           57.751         7.4
# 1         7.6    195321.0          107.137         7.1
# 2         7.5    141937.0           71.160         7.1
# ...

# %%
len(data)
# Out:
# 1057

# %%
data.production_countries.unique()
# Out:
# array(["'US'", "'GB', 'US'", "'GB'", "'CA', 'US'", "'CA'", '',
#        "'US', 'CA'", "'FR'", "'SE', 'US', 'NO'", "'JP', 'US'",
#        "'US', 'GB'", "'FR', 'US', 'AU', 'CA'", "'US', 'SK'",
#        "'FR', 'GB', 'US', 'CA'", "'SUHH'", "'AU', 'US'", "'NZ', 'US'",
#        "'DE', 'US'", "'US', 'JP'", "'PL', 'SI', 'US', 'CZ'", "'SG', 'US'",
#        "'GB', 'US', 'HU'", "'GB', 'US', 'DE', 'IE'",
#        "'ES', 'CH', 'FR', 'MC'", "'CA', 'US', 'AU'", "'DE'",
#        "'HK', 'US', 'CN'", "'CN'", "'US', 'BR'", "'AR'", "'IN', 'US'",
#        "'CI', 'UG', 'US'", "'FR', 'US'", "'NL'", "'MX', 'US'",
#        "'US', 'AU', 'GB'", "'US', 'FR', 'KR'", "'BE', 'GB', 'US'",
#        "'GB', 'DE', 'US'", "'AU', 'GB', 'US'", "'IT'", "'US', 'FR'",
#        "'CN', 'GB', 'US'", "'AU'", "'ES', 'US'", "'JP'", "'US', 'CN'",
#        "'DE', 'US', 'FR', 'GB', 'ZA'", "'DK', 'US', 'CA'", "'PH'",
#        "'BR', 'AR'", "'IN'", "'FR', 'GB'", "'US', 'KI'", "'NZ'",
# ...

# %%
data.type.unique()
# Out:
# array(['MOVIE', 'SHOW'], dtype=object)

# %%
data.drop_duplicates(subset="movie",keep="first",inplace=True)

# %%
data
# Out:
#                                        movie   type  \
# 0                                   Fantasia  MOVIE
# 1            Snow White and the Seven Dwarfs  MOVIE
# 2                                  Pinocchio  MOVIE
# 3                                      Bambi  MOVIE
# 4                            Treasure Island  MOVIE
# ...                                      ...    ...
# 1527                             Shark Gangs  MOVIE
# 1528                            Own the Room  MOVIE
# 1529  Built for Mars: The Perseverance Rover  MOVIE
# 1530           Killer Shark vs. Killer Whale  MOVIE
# 1531                   Far From Raven's Home  MOVIE
#
#                                                  genres production_countries  \
# 0           ['animation', 'family', 'music', 'fantasy']                 'US'
# 1     ['fantasy', 'family', 'romance', 'animation', ...                 'US'
# 2          ['animation', 'comedy', 'family', 'fantasy']                 'US'
# ...

# %%
data.movie.value_counts()
# Out:
# Fantasia                                  1
# Snow White and the Seven Dwarfs           1
# Goldie & Bear                             1
# The Lodge                                 1
# Bizaardvark                               1
#                                          ..
# Ice Age: Dawn of the Dinosaurs            1
# Ice Age: The Meltdown                     1
# The Avengers: Earth's Mightiest Heroes    1
# Around the World in 80 Days               1
# Far From Raven's Home                     1
# Name: movie, Length: 1024, dtype: int64

# %%
top_100=data[data["imdb_votes"]>5000].sort_values(by="imdb_score",ascending=False).head(100)
top_100
# Out:
#                         movie   type  \
# 1015                    Bluey   SHOW
# 1151  Cosmos: Possible Worlds   SHOW
# 1367    The Beatles: Get Back   SHOW
# 1142          The Mandalorian   SHOW
# 1035         One Strange Rock   SHOW
# ...                       ...    ...
# 231                  TaleSpin   SHOW
# 88           The Muppet Movie  MOVIE
# 230        The Little Mermaid  MOVIE
# 329              Even Stevens   SHOW
# 1031            Incredibles 2  MOVIE
#
#                                                  genres production_countries  \
# 1015                            ['animation', 'family']                 'AU'
# 1151    ['documentation', 'drama', 'thriller', 'scifi']                 'US'
# 1367                         ['documentation', 'music']     'NZ', 'GB', 'US'
# 1142                     ['scifi', 'action', 'fantasy']                 'US'
# 1035                                  ['documentation']                 'US'
# ...

# %%
#top_100=data.sort_values(by="imdb_score",ascending=False)
#top_100
# Out:
#                                                   movie   type  \
# 1015                                              Bluey   SHOW
# 1151                            Cosmos: Possible Worlds   SHOW
# 1252                               Alaska Animal Rescue   SHOW
# 1367                              The Beatles: Get Back   SHOW
# 1184                                Heartland Docs, DVM   SHOW
# ...                                                 ...    ...
# 1117     Billy Dilley’s Super-Duper Subterranean Summer   SHOW
# 334                                              Kazaam  MOVIE
# 541                                        Home Alone 4  MOVIE
# 663   Hannah Montana & Miley Cyrus: Best of Both Wor...  MOVIE
# 685              Jonas Brothers: The Concert Experience  MOVIE
#
#                                                  genres production_countries  \
# 1015                            ['animation', 'family']                 'AU'
# ...

# %%
top_100["Rank"]=top_100["imdb_score"].rank(method="first",ascending=False)
top_100
# Out:
#                         movie   type  \
# 1015                    Bluey   SHOW
# 1151  Cosmos: Possible Worlds   SHOW
# 1367    The Beatles: Get Back   SHOW
# 1142          The Mandalorian   SHOW
# 1035         One Strange Rock   SHOW
# ...                       ...    ...
# 231                  TaleSpin   SHOW
# 88           The Muppet Movie  MOVIE
# 230        The Little Mermaid  MOVIE
# 329              Even Stevens   SHOW
# 1031            Incredibles 2  MOVIE
#
#                                                  genres production_countries  \
# 1015                            ['animation', 'family']                 'AU'
# 1151    ['documentation', 'drama', 'thriller', 'scifi']                 'US'
# 1367                         ['documentation', 'music']     'NZ', 'GB', 'US'
# 1142                     ['scifi', 'action', 'fantasy']                 'US'
# 1035                                  ['documentation']                 'US'
# ...

# %%
top_100[top_100["type"]!="SHOW"]
# Out:
#                         movie   type  \
# 93    The Empire Strikes Back  MOVIE
# 85                  Star Wars  MOVIE
# 290             The Lion King  MOVIE
# 1144                 Hamilton  MOVIE
# 1378               The Rescue  MOVIE
# ...                       ...    ...
# 104           The Jungle Book  MOVIE
# 298                     Mulan  MOVIE
# 88           The Muppet Movie  MOVIE
# 230        The Little Mermaid  MOVIE
# 1031            Incredibles 2  MOVIE
#
#                                                  genres production_countries  \
# 93                       ['scifi', 'action', 'fantasy']                 'US'
# 85                       ['scifi', 'action', 'fantasy']                 'US'
# 290                    ['drama', 'family', 'animation']                 'US'
# 1144                      ['drama', 'history', 'music']                 'US'
# 1378   ['action', 'thriller', 'drama', 'documentation']                 'US'
# ...

# %% [markdown]
# popular genres

# %%
data.imdb_votes.max()
# Out:
# 1353907.0

# %%
tempgenre=data.genres.str.split(",",expand=True).iloc[:,0:2]
tempgenre.rename(columns={0:"Genre1",1:"Genre2"})
# Out:
#                  Genre1      Genre2
# 0          ['animation'    'family'
# 1            ['fantasy'    'family'
# 2          ['animation'    'comedy'
# 3          ['animation'     'drama'
# 4             ['family'   'action']
# ...                 ...         ...
# 1527  ['documentation']        None
# 1528  ['documentation']        None
# 1529  ['documentation']        None
# 1530  ['documentation']        None
# 1531       ['animation'   'comedy']
#
# [1024 rows x 2 columns]

# %%
#tempgenre.Genre2.fillna(tempgenre.Genre1,inplace=True)
#tempgenre
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4992/3615638033.py in <module>
# ----> 1 tempgenre.Genre2.fillna(tempgenre.Genre1,inplace=True)
#       2 tempgenre
#
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Genre2'

# %%
data.imdb_votes.min()
# Out:
# 5.0

# %%
data.imdb_votes.mean()
# Out:
# 78586.1650390625
