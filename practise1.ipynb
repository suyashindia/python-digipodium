# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/Dell/Downloads/covid 19/data.csv")

# %%
data.head()
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE  Population Continent  \
# 0  Afghanistan  Afghanistan                     AFG    40462186      Asia
# 1      Albania      Albania                     ALB     2872296    Europe
# 2      Algeria      Algeria                     DZA    45236699    Africa
# 3      Andorra      Andorra                     AND       77481    Europe
# 4       Angola       Angola                     AGO    34654212    Africa
#
#    Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# 0       177827          7671               4395                190
# 1       273870          3492              95349               1216
# 2       265691          6874               5873                152
# 3        40024           153             516565               1975
# 4        99194          1900               2862                 55
#
#    Death percentage
# 0          4.313743
# 1          1.275058
# 2          2.587216
# 3          0.382271
# ...

# %%
data.tail()
# Out:
#                Country                Other names ISO 3166-1 alpha-3 CODE  \
# 220  Wallis and Futuna  Wallis and Futuna Islands                     WLF
# 221     Western Sahara             Western Sahara                   ESHÂ
# 222              Yemen                      Yemen                     YEM
# 223             Zambia                     Zambia                     ZMB
# 224           Zimbabwe                   Zimbabwe                     ZWE
#
#      Population Continent  Total Cases  Total Deaths  Tot Cases//1M pop  \
# 220       10894   Oceania          454             7              41674
# 221      623031    Africa           10             1                 16
# 222    30975258      Asia        11806          2143                381
# 223    19284482    Africa       317076          3967              16442
# 224    15241601    Africa       246525          5446              16174
#
#      Tot Deaths/1M pop  Death percentage
# 220                643          1.541850
# ...

# %%
data.describe()
# Out:
#          Population   Total Cases  Total Deaths  Tot Cases//1M pop  \
# count  2.250000e+02  2.250000e+02  2.250000e+02         225.000000
# mean   3.507321e+07  2.184781e+06  2.744813e+04      136900.373333
# std    1.392418e+08  7.275938e+06  9.689177e+04      145060.340289
# min    8.050000e+02  1.000000e+00  0.000000e+00           9.000000
# 25%    5.665570e+05  2.407100e+04  1.890000e+02       11384.000000
# 50%    5.827911e+06  1.639360e+05  1.965000e+03       88987.000000
# 75%    2.190585e+07  1.092547e+06  1.366000e+04      223335.000000
# max    1.439324e+09  8.183905e+07  1.008222e+06      696044.000000
#
#        Tot Deaths/1M pop  Death percentage
# count         225.000000        225.000000
# mean         1096.715556          1.444125
# std          1195.715543          1.741728
# min             0.000000          0.000000
# 25%           123.000000          0.511291
# 50%           708.000000          1.036905
# 75%          1795.000000          1.977017
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  225 non-null    object
#  1   Other names              224 non-null    object
#  2   ISO 3166-1 alpha-3 CODE  225 non-null    object
#  3   Population               225 non-null    int64
#  4   Continent                225 non-null    object
#  5   Total Cases              225 non-null    int64
#  6   Total Deaths             225 non-null    int64
#  7   Tot Cases//1M pop        225 non-null    int64
#  8   Tot Deaths/1M pop        225 non-null    int64
#  9   Death percentage         225 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 17.7+ KB

# %%
data.columns.unique()
# Out:
# Index(['Country', 'Other names', 'ISO 3166-1 alpha-3 CODE', 'Population',
#        'Continent', 'Total Cases', 'Total Deaths', 'Tot Cases//1M pop',
#        'Tot Deaths/1M pop', 'Death percentage'],
#       dtype='object')

# %%
data=data.drop(["Other names","ISO 3166-1 alpha-3 CODE"],axis=1)
data
# Out:
#                Country  Population Continent  Total Cases  Total Deaths  \
# 0          Afghanistan    40462186      Asia       177827          7671
# 1              Albania     2872296    Europe       273870          3492
# 2              Algeria    45236699    Africa       265691          6874
# 3              Andorra       77481    Europe        40024           153
# 4               Angola    34654212    Africa        99194          1900
# ..                 ...         ...       ...          ...           ...
# 220  Wallis and Futuna       10894   Oceania          454             7
# 221     Western Sahara      623031    Africa           10             1
# 222              Yemen    30975258      Asia        11806          2143
# 223             Zambia    19284482    Africa       317076          3967
# 224           Zimbabwe    15241601    Africa       246525          5446
#
#      Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# ...

# %%
data.head()
# Out:
#        Country  Population Continent  Total Cases  Total Deaths  \
# 0  Afghanistan    40462186      Asia       177827          7671
# 1      Albania     2872296    Europe       273870          3492
# 2      Algeria    45236699    Africa       265691          6874
# 3      Andorra       77481    Europe        40024           153
# 4       Angola    34654212    Africa        99194          1900
#
#    Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 0               4395                190          4.313743
# 1              95349               1216          1.275058
# 2               5873                152          2.587216
# 3             516565               1975          0.382271
# 4               2862                 55          1.915438

# %%
data.Country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei ',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia',
#        'Cameroon', 'Canada', 'CAR', 'Caribbean Netherlands',
#        'Cayman Islands', 'Chad', 'Channel Islands', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo', 'Cook Islands', 'Costa Rica',
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic',
#        'Democratic Republic of the Congo', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
# ...

# %%
india=(data["Country"]=="India")
df_india=data[india]
df_india.head()
# Out:
#    Country  Population Continent  Total Cases  Total Deaths  \
# 92   India  1403754381      Asia     43029044        521388
#
#     Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 92              30653                371          1.211712

# %%
asia=(data["Continent"]=="Asia")
df_asia=data[asia]
df_asia.head()
# Out:
#         Country  Population Continent  Total Cases  Total Deaths  \
# 0   Afghanistan    40462186      Asia       177827          7671
# 8       Armenia     2972939      Asia       422574          8617
# 12   Azerbaijan    10299156      Asia       792061          9697
# 14      Bahrain     1804995      Asia       556241          1471
# 15   Bangladesh   167561502      Asia      1951770         29122
#
#     Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 0                4395                190          4.313743
# 8              142140               2898          2.039169
# 12              76905                942          1.224274
# 14             308168                815          0.264454
# 15              11648                174          1.492082

# %%
data.isnull().sum()
# Out:
# Country              0
# Population           0
# Continent            0
# Total Cases          0
# Total Deaths         0
# Tot Cases//1M pop    0
# Tot Deaths/1M pop    0
# Death percentage     0
# dtype: int64

# %%
df_asia.Country.unique()
# Out:
# array(['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Bhutan', 'Brunei ', 'Cambodia', 'China', 'Cyprus', 'Georgia',
#        'Hong Kong', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel',
#        'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos',
#        'Lebanon', 'Macao', 'Malaysia', 'Maldives', 'Mongolia', 'Myanmar',
#        'Nepal', 'Oman', 'Pakistan', 'Palestine', 'Philippines', 'Qatar',
#        'S. Korea', 'Saudi Arabia', 'Singapore', 'Sri Lanka', 'Syria',
#        'Taiwan', 'Tajikistan', 'Thailand', 'Timor-Leste', 'Turkey', 'UAE',
#        'Uzbekistan', 'Vietnam', 'Yemen'], dtype=object)

# %%
df_asia["Total Cases"].max()
# Out:
# 43029044

# %%
df_asia["Total Cases"].min()
# Out:
# 82

# %%
plt.figure(figsize=(16,10))

ax=sns.barplot(x="Death percentage",y="Country",data=df_asia)
plt.xticks(rotation=90)
plt.show()

# %%
df_asia.head()
# Out:
#         Country  Population Continent  Total Cases  Total Deaths  \
# 0   Afghanistan    40462186      Asia       177827          7671
# 8       Armenia     2972939      Asia       422574          8617
# 12   Azerbaijan    10299156      Asia       792061          9697
# 14      Bahrain     1804995      Asia       556241          1471
# 15   Bangladesh   167561502      Asia      1951770         29122
#
#     Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 0                4395                190          4.313743
# 8              142140               2898          2.039169
# 12              76905                942          1.224274
# 14             308168                815          0.264454
# 15              11648                174          1.492082

# %%
 df_asia["Active Cases"]=df_asia["Total Cases"]-df_asia["Total Deaths"]
 df_asia
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_4112/1613048338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_asia["Active Cases"]=df_asia["Total Cases"]-df_asia["Total Deaths"]
#           Country  Population Continent  Total Cases  Total Deaths  \
# 0     Afghanistan    40462186      Asia       177827          7671
# 8         Armenia     2972939      Asia       422574          8617
# 12     Azerbaijan    10299156      Asia       792061          9697
# 14        Bahrain     1804995      Asia       556241          1471
# 15     Bangladesh   167561502      Asia      1951770         29122
# 22         Bhutan      786480      Asia        31437            12
# 28        Brunei       444812      Asia       135974           213
# ...

# %%
country_withlessthan1lakhcase=df_asia.Country[df_asia.Cases<100000].value_counts()
country_withlessthan1lakhcase
# Out:
# Bhutan         1
# Macao          1
# Syria          1
# Taiwan         1
# Tajikistan     1
# Timor-Leste    1
# Yemen          1
# Name: Country, dtype: int64

# %%
df_aisa=df_asia.rename(columns={"Total Cases":"Cases"},inplace=True)
df_asia.head()
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#         Country  Population Continent    Cases  Total Deaths  \
# 0   Afghanistan    40462186      Asia   177827          7671
# 8       Armenia     2972939      Asia   422574          8617
# 12   Azerbaijan    10299156      Asia   792061          9697
# 14      Bahrain     1804995      Asia   556241          1471
# 15   Bangladesh   167561502      Asia  1951770         29122
#
#     Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage  Active Cases
# 0                4395                190          4.313743        170156
# 8              142140               2898          2.039169        413957
# ...

# %%
country_group=df_asia.groupby(["Country"])
country_group

# %%
country_group.get_group("Iran")
# Out:
#    Country  Population Continent    Cases  Total Deaths  Tot Cases//1M pop  \
# 94    Iran    85874667      Asia  7167646        140315              83466
#
#     Tot Deaths/1M pop  Death percentage  Active Cases
# 94               1634          1.957616       7027331

# %%
country_group["Active Cases"].value_counts().head(10)
# Out:
# Country      Active Cases
# Afghanistan  170156          1
# Armenia      413957          1
# Azerbaijan   782364          1
# Bahrain      554770          1
# Bangladesh   1922648         1
# Brunei       135761          1
# Cambodia     132693          1
# China        150100          1
# Cyprus       439017          1
# Georgia      1632466         1
# Name: Active Cases, dtype: int64

# %%
country_group["Active Cases"].value_counts().loc["India"]
# Out:
# Active Cases
# 42507656    1
# Name: Active Cases, dtype: int64

# %%
for Country,df_asia in country_group:
    print(Country)
    print(df_asia)
# Out:
# Afghanistan
#        Country  Population Continent   Cases  Total Deaths  Tot Cases//1M pop  \
# 0  Afghanistan    40462186      Asia  177827          7671               4395
#
#    Tot Deaths/1M pop  Death percentage  Active Cases
# 0                190          4.313743        170156
# Armenia
#    Country  Population Continent   Cases  Total Deaths  Tot Cases//1M pop  \
# 8  Armenia     2972939      Asia  422574          8617             142140
#
#    Tot Deaths/1M pop  Death percentage  Active Cases
# 8               2898          2.039169        413957
# Azerbaijan
#        Country  Population Continent   Cases  Total Deaths  Tot Cases//1M pop  \
# 12  Azerbaijan    10299156      Asia  792061          9697              76905
#
#     Tot Deaths/1M pop  Death percentage  Active Cases
# 12                942          1.224274        782364
# Bahrain
#     Country  Population Continent   Cases  Total Deaths  Tot Cases//1M pop  \
# ...

# %%
def handlecountries(value):
    if(value in country_withlessthan1lakhcase):
        return "others"
    else:
        return value
df_asia["Country"]=df_asia["Country"].apply(handlecountries)
df_asia["Country"].value_counts()
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_4112/2470157314.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_asia["Country"]=df_asia["Country"].apply(handlecountries)
# others          7
# Afghanistan     1
# Philippines     1
# Malaysia        1
# Maldives        1
# Mongolia        1
# Myanmar         1
# Nepal           1
# Oman            1
# Pakistan        1
# Palestine       1
# Qatar           1
# Laos            1
# S. Korea        1
# Saudi Arabia    1
# Singapore       1
# Sri Lanka       1
# Thailand        1
# Turkey          1
# UAE             1
# Uzbekistan      1
# Lebanon         1
# Kyrgyzstan      1
# Armenia         1
# Kuwait          1
# Azerbaijan      1
# Bahrain         1
# Bangladesh      1
# ...

# %%
plt.figure(figsize=(16,10))
sns.barplot(x="Country",y="Cases",data=df_asia)
plt.xticks(rotation=90)
plt.show()
