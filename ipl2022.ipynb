# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
runs_scored_by_buttler=pd.DataFrame(runs_scored_by_buttler)
runs_scored_by_buttler
# Out:
#    batsman_run
# 0          247
# 1          185
# 4           84
# 6           45
# 2           33
# 3            2

# %%
df1=ball_data.groupby(["batter"])["total_run"].sum()
df1.to_csv("batsmen_runs.csv")
df1=pd.read_csv("batsmen_runs.csv")
# df1=pd.pivot_table(df1,values=None,index=["batter"],columns=["total_run"],fill_value=0,aggfunc=np.sum)
df1
# Out:
#                 batter  total_run
# 0             A Badoni        173
# 1            A Manohar        112
# 2             A Nortje          2
# 3              A Tomar          4
# 4           AD Russell        349
# ..                 ...        ...
# 169            WP Saha        335
# 170  Washington Sundar        113
# 171        YBK Jaiswal        272
# 172          YS Chahal          5
# 173         Yash Dayal          0
#
# [174 rows x 2 columns]

# %%
xyz=ball_data.groupby(["batter","total_run"]).count()
xyz
# Out:
#                        ID  innings  overs  ballnumber  bowler  non-striker  \
# batter      total_run
# A Badoni    0          47       47     47          47      47           47
#             1          62       62     62          62      62           62
#             2          11       11     11          11      11           11
#             3           1        1      1           1       1            1
#             4          11       11     11          11      11           11
# ...                    ..      ...    ...         ...     ...          ...
# YBK Jaiswal 6          10       10     10          10      10           10
# YS Chahal   0           4        4      4           4       4            4
#             1           3        3      3           3       3            3
#             2           1        1      1           1       1            1
# Yash Dayal  0           1        1      1           1       1            1
#
# ...

# %%
runs_scored_by_buttler=df_buttler.batsman_run.value_counts()
runs_scored_by_buttler
# Out:
# 0    247
# 1    185
# 4     84
# 6     45
# 2     33
# 3      2
# Name: batsman_run, dtype: int64

# %%
match_data=pd.read_csv("C:/Users/Dell/Downloads/ipl matches 2022/data.csv")
ball_data=pd.read_csv("C:/Users/Dell/Downloads/ipl ball by ball 2022/data.csv")

# %%
match_data.head()
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29    2022        Final
# 1  1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25    2022   Eliminator
# 3  1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
gujrat_titans=(match_data["Team1"]=="Gujarat Titans")
df_gujrat_titans=match_data[gujrat_titans].copy()
df_gujrat_titans.head()
# Out:
#          ID         City        Date  Season MatchNumber           Team1  \
# 7   1304113       Mumbai  2022-05-19    2022          67  Gujarat Titans
# 17  1304103         Pune  2022-05-10    2022          57  Gujarat Titans
# 26  1304094  Navi Mumbai  2022-05-03    2022          48  Gujarat Titans
# 39  1304081  Navi Mumbai  2022-04-23    2022          35  Gujarat Titans
# 50  1304070       Mumbai  2022-04-14    2022          24  Gujarat Titans
#
#                           Team2  \
# 7   Royal Challengers Bangalore
# 17         Lucknow Super Giants
# 26                 Punjab Kings
# 39        Kolkata Knight Riders
# 50             Rajasthan Royals
#
#                                             Venue        TossWinner  \
# 7                        Wankhede Stadium, Mumbai    Gujarat Titans
# 17  Maharashtra Cricket Association Stadium, Pune    Gujarat Titans
# 26             Dr DY Patil Sports Academy, Mumbai    Gujarat Titans
# ...

# %%
df_gujrat_titans['venue']=df_gujrat_titans['Venue'].apply(lambda v: v.split(',')[0])

# %%
df_gujrat_titans
# Out:
#          ID         City        Date  Season MatchNumber           Team1  \
# 7   1304113       Mumbai  2022-05-19    2022          67  Gujarat Titans
# 17  1304103         Pune  2022-05-10    2022          57  Gujarat Titans
# 26  1304094  Navi Mumbai  2022-05-03    2022          48  Gujarat Titans
# 39  1304081  Navi Mumbai  2022-04-23    2022          35  Gujarat Titans
# 50  1304070       Mumbai  2022-04-14    2022          24  Gujarat Titans
# 53  1304067       Mumbai  2022-04-11    2022          21  Gujarat Titans
# 64  1304056         Pune  2022-04-02    2022          10  Gujarat Titans
#
#                           Team2  \
# 7   Royal Challengers Bangalore
# 17         Lucknow Super Giants
# 26                 Punjab Kings
# 39        Kolkata Knight Riders
# 50             Rajasthan Royals
# 53          Sunrisers Hyderabad
# 64               Delhi Capitals
#
#                                             Venue           TossWinner  \
# ...

# %%
match_data.Team1.unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians'], dtype=object)

# %%
ball_data.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
buttler=(ball_data["batter"]=="JC Buttler")
df_buttler=ball_data[buttler]
df_buttler.head()
# Out:
#         ID  innings  overs  ballnumber      batter          bowler  \
# 2  1312200        1      0           3  JC Buttler  Mohammed Shami
# 6  1312200        1      1           1  JC Buttler      Yash Dayal
# 7  1312200        1      1           2  JC Buttler      Yash Dayal
# 8  1312200        1      1           3  JC Buttler      Yash Dayal
# 9  1312200        1      1           4  JC Buttler      Yash Dayal
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 2  YBK Jaiswal        NaN            1           0          1             0
# 6  YBK Jaiswal        NaN            0           0          0             0
# 7  YBK Jaiswal        NaN            0           0          0             0
# 8  YBK Jaiswal        NaN            4           0          4             0
# 9  YBK Jaiswal        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
dismisal_of_buttler=df_buttler.kind.value_counts()
dismisal_of_buttler.plot(kind="pie")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
MOM_awards=match_data.Player_of_Match.value_counts()
MOM_awards.plot(kind="bar",figsize=(16,10))
plt.show()

# %%
match_data.drop(["Team1Players","Team2Players","SuperOver","method"],axis=1,inplace=True)

# %%
match_data.Venue.unique()
# Out:
# array(['Narendra Modi Stadium, Ahmedabad', 'Eden Gardens, Kolkata',
#        'Wankhede Stadium, Mumbai', 'Brabourne Stadium, Mumbai',
#        'Dr DY Patil Sports Academy, Mumbai',
#        'Maharashtra Cricket Association Stadium, Pune'], dtype=object)

# %%
Team_and_toss_win=match_data.TossWinner.value_counts()
Team_and_toss_win
# Out:
# Gujarat Titans                 10
# Sunrisers Hyderabad            10
# Mumbai Indians                  9
# Kolkata Knight Riders           8
# Royal Challengers Bangalore     8
# Delhi Capitals                  8
# Lucknow Super Giants            7
# Chennai Super Kings             6
# Rajasthan Royals                4
# Punjab Kings                    4
# Name: TossWinner, dtype: int64

# %%
Team_and_toss_win.plot(kind="bar",figsize=(16,10))
plt.show()

# %%
most_preferred_decision=match_data.TossDecision.value_counts()
most_preferred_decision.plot(kind="bar",figsize=(10,5))
plt.show()

# %%
match_data.head()
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29    2022        Final
# 1  1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25    2022   Eliminator
# 3  1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
match_data.Margin[match_data["WonBy"]!="Wickets"].max()
# Out:
# 91

# %%
match_data.Margin[match_data["WonBy"]!="Runs"].max()
# Out:
# 9

# %%
top_10=match_data[match_data["WonBy"]!="Wickets"].sort_values(by="Margin",ascending=False).head(10)
top_10
# Out:
#          ID         City        Date  Season MatchNumber  \
# 19  1304101  Navi Mumbai  2022-05-08    2022          55
# 21  1304099         Pune  2022-05-07    2022          53
# 20  1304100       Mumbai  2022-05-08    2022          54
# 17  1304103         Pune  2022-05-10    2022          57
# 69  1304051         Pune  2022-03-29    2022           5
# 63  1304057       Mumbai  2022-04-03    2022          11
# 13  1304107         Pune  2022-05-14    2022          61
# 14  1304106       Mumbai  2022-05-13    2022          60
# 18  1304102  Navi Mumbai  2022-05-09    2022          56
# 54  1304065       Mumbai  2022-04-10    2022          19
#
#                           Team1                        Team2  \
# 19          Chennai Super Kings               Delhi Capitals
# 21         Lucknow Super Giants        Kolkata Knight Riders
# 20  Royal Challengers Bangalore          Sunrisers Hyderabad
# 17               Gujarat Titans         Lucknow Super Giants
# ...

# %%
Matches_held_at_each_stadium=match_data.Venue.value_counts()
Matches_held_at_each_stadium.plot(kind="bar",figsize=(16,10))
plt.show()

# %%
Matches_held_at_each_stadium=match_data.Venue.value_counts()
Matches_held_at_each_stadium
# Out:
# Wankhede Stadium, Mumbai                         21
# Dr DY Patil Sports Academy, Mumbai               20
# Brabourne Stadium, Mumbai                        16
# Maharashtra Cricket Association Stadium, Pune    13
# Narendra Modi Stadium, Ahmedabad                  2
# Eden Gardens, Kolkata                             2
# Name: Venue, dtype: int64

# %%
Venue_suitable_for_Batting=match_data.Venue[match_data.WonBy!="Wickets"].value_counts()
Venue_suitable_for_Batting.plot(kind="bar",figsize=(16,10))
# Out:
# <AxesSubplot:>

# %%
Venue_suitable_for_Bowling=match_data.Venue[match_data.WonBy!="Runs"].value_counts()
Venue_suitable_for_Bowling.plot(kind="bar",figsize=(16,10))
plt.show()

# %%
Team_with_match_wins=match_data["WinningTeam"].value_counts()
Team_with_match_wins.plot(kind="bar",figsize=(16,10))
plt.show()

# %%
Toss=match_data["TossWinner"]==match_data["WinningTeam"]
sns.countplot(x=Toss)
plt.show()

# %%
Team_winning_most_by_batting=match_data.Team1[match_data["WonBy"]!="Wickets"].value_counts()
Team_winning_most_by_batting.plot(kind="bar",figsize=(16,10))
plt.show()

# %%
Team_winning_most_by_bowling=match_data.Team1[match_data["WonBy"]!="Runs"].value_counts()
Team_winning_most_by_bowling.plot(kind="bar",figsize=(16,10))
plt.show()
