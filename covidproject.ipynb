# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
#value counts
data["drive-wheels"].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
data["drive-wheels"].value_counts() #decreasng order
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drive-wheels, dtype: int64

# %%
#datetime index
 #data.loc[0,"date"]  
 #date.loc[0,"date"].day_name()
#data["date"]=pd.to_datetime(data["Date"],format=%Y-%m-%d %I-%p)

# %%
data.groupby
# Out:
# <bound method DataFrame.groupby of      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero      None        std
# 1            3                 ?  alfa-romero      None        std
# 2            1                 ?  alfa-romero      None        std
# 3            2               164         audi      None        std
# 4            2               164         audi      None        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo      None        std
# 201         -1                95        volvo      None      turbo
# 202         -1                95        volvo      None        std
# 203         -1                95        volvo      None      turbo
# 204         -1                95        volvo      None      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
data.columns.unique
# Out:
# <bound method Index.unique of Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')>

# %%
#count function
data["drive-wheels"].count()
# Out:
# 205

# %%
#groupby fx
data=data.groupby(fuel-type)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7520/2323333325.py in <module>
#       1 #groupby fx
# ----> 2 data=data.groupby(fuel-type)
#
# NameError: name 'fuel' is not defined

# %%
#series.all()
data.all
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.all of      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero      None        std
# 1            3                 ?  alfa-romero      None        std
# 2            1                 ?  alfa-romero      None        std
# 3            2               164         audi      None        std
# 4            2               164         audi      None        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo      None        std
# 201         -1                95        volvo      None      turbo
# 202         -1                95        volvo      None        std
# 203         -1                95        volvo      None      turbo
# 204         -1                95        volvo      None      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
style.use("ggplot")
x=["wheel-base"]
y=["length"]
plt.plot(x,y,"g",label="line one",linewidth=5)
plt.title("info")
plt.ylabel("y axis")
plt.xlabel("x axis")
plt.legend()
plt.grid(True,color="k")

# %%
data.iloc[4,4]
# Out:
# 'std'

# %%
#is

# %%
data["fuel-type"]=None #will make all values at given entity as none

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
x=[5,8,10]
y=[12,16,6]
x2=[6,9,11]
y2=[6,16,7]
plt.plot(x,y,"g",label="line one",linewidth=5)
plt.plot(x2,y2,"c",label="line two",linewidth=5)
plt.title("epic info")
plt.ylabel("y axis")
plt.xlabel("x axis")
plt.legend()
plt.grid(True,color="k")

# %%
data.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo      None        std         four
# 201         -1                95  volvo      None      turbo         four
# 202         -1                95  volvo      None        std         four
# 203         -1                95  volvo      None      turbo         four
# 204         -1                95  volvo      None      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
data.loc[(data[int("bore")<4])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2832/825122360.py in <module>
# ----> 1 data.loc[(data[int("bore")<4])]
#
# ValueError: invalid literal for int() with base 10: 'bore'

# %%
#axis=0(row)
#axis=1(column)

# %%
data.drop("normalized-losses",axis=1) #in order to drop a particular column or row,for row use axis=0
# Out:
#      symboling         make fuel-type aspiration num-of-doors   body-style  \
# 0            3  alfa-romero       gas        std          two  convertible
# 1            3  alfa-romero       gas        std          two  convertible
# 2            1  alfa-romero       gas        std          two    hatchback
# 3            2         audi       gas        std         four        sedan
# 4            2         audi       gas        std         four        sedan
# ..         ...          ...       ...        ...          ...          ...
# 200         -1        volvo       gas        std         four        sedan
# 201         -1        volvo       gas      turbo         four        sedan
# 202         -1        volvo       gas        std         four        sedan
# 203         -1        volvo    diesel      turbo         four        sedan
# 204         -1        volvo       gas      turbo         four        sedan
#
# ...

# %%
data.loc[[195,196],["engine-location","wheel-base"]] #to extract a particular entity
# Out:
#     engine-location  wheel-base
# 195           front       104.3
# 196           front       104.3

# %%
#to get all columns
#data.loc[:,["C","D"]]

#to get all rows
#data.loc[[1,2],:]

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data=pd.read_csv("https://raw.githubusercontent.com/digipodium/Datasets/main/automobile.csv",index_col=0)

# %%
data.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo      None        std         four
# 201         -1                95  volvo      None      turbo         four
# 202         -1                95  volvo      None        std         four
# 203         -1                95  volvo      None      turbo         four
# 204         -1                95  volvo      None      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
data.shape
# Out:
# (205, 26)

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero      None        std
# 1            3                 ?  alfa-romero      None        std
# 2            1                 ?  alfa-romero      None        std
# 3            2               164         audi      None        std
# 4            2               164         audi      None        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo      None        std
# 201         -1                95        volvo      None      turbo
# 202         -1                95        volvo      None        std
# 203         -1                95        volvo      None      turbo
# 204         -1                95        volvo      None      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
data.info
# Out:
# <bound method DataFrame.info of      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
#to remove index
data.to_csv("https://raw.githubusercontent.com/digipodium/Datasets/main/automobile.csv",index=False)

# %%
data.head(2)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
#
# [2 rows x 26 columns]

# %%
data["stroke"][1]=3.68 #to change the value in data
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_2832/175002361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["stroke"][1]=3.68 #to change the value in data

# %%
data.head(2) #data changed
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    3.68               9.0        111      5000       21
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
#
# [2 rows x 26 columns]

# %%
ser=pd.Series(np.random.rand(24))

# %%
ser
# Out:
# 0     0.159520
# 1     0.102594
# 2     0.221906
# 3     0.934646
# 4     0.196891
# 5     0.838966
# 6     0.827652
# 7     0.674149
# 8     0.455988
# 9     0.295093
# 10    0.014889
# 11    0.688476
# 12    0.287919
# 13    0.973605
# 14    0.768442
# 15    0.344674
# 16    0.814811
# 17    0.036976
# 18    0.749603
# 19    0.116787
# 20    0.028075
# 21    0.318847
# 22    0.185675
# 23    0.510637
# dtype: float64

# %%
#convert data into a numpy array
data.to_numpy()
# Out:
# array([[3, '?', 'alfa-romero', ..., 21, 27, '13495'],
#        [3, '?', 'alfa-romero', ..., 21, 27, '16500'],
#        [1, '?', 'alfa-romero', ..., 19, 26, '16500'],
#        ...,
#        [-1, '95', 'volvo', ..., 18, 23, '21485'],
#        [-1, '95', 'volvo', ..., 26, 27, '22470'],
#        [-1, '95', 'volvo', ..., 19, 25, '22625']], dtype=object)

# %%
#to chnage rows into colums and vice versa
data.T
# Out:
#                            0            1            2      3      4      5    \
# symboling                    3            3            1      2      2      2
# normalized-losses            ?            ?            ?    164    164      ?
# make               alfa-romero  alfa-romero  alfa-romero   audi   audi   audi
# fuel-type                  gas          gas          gas    gas    gas    gas
# aspiration                 std          std          std    std    std    std
# num-of-doors               two          two          two   four   four    two
# body-style         convertible  convertible    hatchback  sedan  sedan  sedan
# drive-wheels               rwd          rwd          rwd    fwd    4wd    fwd
# engine-location          front        front        front  front  front  front
# wheel-base                88.6         88.6         94.5   99.8   99.4   99.8
# length                   168.8        168.8        171.2  176.6  176.6  177.3
# ...

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...
