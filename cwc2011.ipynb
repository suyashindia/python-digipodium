# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/Dell/Downloads/2011 cwc/data.csv")

# %%
data.head()
# Out:
#    in  ball      batsmen  bowler non_striker  runs  extras  total  wicket  \
# 0   0   0.1  WU Tharanga  Z Khan  TM Dilshan     0       0      0       0
# 1   1   0.2  WU Tharanga  Z Khan  TM Dilshan     0       0      0       0
# 2   2   0.3  WU Tharanga  Z Khan  TM Dilshan     0       0      0       0
# 3   3   0.4  WU Tharanga  Z Khan  TM Dilshan     0       0      0       0
# 4   4   0.5  WU Tharanga  Z Khan  TM Dilshan     0       1      1       0
#
#   kind player_out  innings       Team  match_no
# 0                        1  Sri Lanka        49
# 1                        1  Sri Lanka        49
# 2                        1  Sri Lanka        49
# 3                        1  Sri Lanka        49
# 4                        1  Sri Lanka        49
